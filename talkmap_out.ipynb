# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Assuming you are working in a Linux or Windows Subsystem for Linux environment, you may need to install some dependencies. Assuming a clean installation, the following will be needed:
#
# ```bash
# sudo apt install jupyter
# sudo apt install python3-pip
# pip install python-frontmatter getorg --upgrade
# ```
#
# After which you can run this from the `_talks/` directory, via:
#
# ```bash
#  jupyter nbconvert --to notebook --execute talkmap.ipynb --output talkmap_out.ipynb
# ```
#
# The `_talks/` directory contains `.md` files of all your talks. This scrapes the location YAML field from each `.md` file, geolocates it with `geopy/Nominatim`, and uses the `getorg` library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# Start by installing the dependencies
# !pip install python-frontmatter getorg --upgrade
import frontmatter
import glob
import getorg
import time
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Collecting python-frontmatter
#   Downloading python_frontmatter-1.3.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: getorg in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (0.3.1)
# Requirement already satisfied: pyyaml in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from python-frontmatter) (6.0.3)
# Requirement already satisfied: geopy in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from getorg) (2.5.0)
# Requirement already satisfied: pygithub in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from getorg) (2.9.1)
# Requirement already satisfied: retrying in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from getorg) (1.4.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from geopy->getorg) (2.1)
# Requirement already satisfied: pynacl>=1.4.0 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from pygithub->getorg) (1.6.2)
# Requirement already satisfied: requests>=2.14.0 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from pygithub->getorg) (2.34.2)
# Requirement already satisfied: pyjwt>=2.4.0 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.13.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from pygithub->getorg) (4.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from pygithub->getorg) (2.7.0)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (49.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.1.0)
# Requirement already satisfied: pycparser in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (3.18)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (2026.7.22)
# Downloading python_frontmatter-1.3.0-py3-none-any.whl (10 kB)
# Installing collected packages: python-frontmatter
# Successfully installed python-frontmatter-1.3.0
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
# Collect the Markdown files
g = glob.glob("_talks/*.md")
print("NUMBER OF FILES =", len(g))

for f in sorted(g):
    print(f)
# Out:
# NUMBER OF FILES = 39
# _talks/2015-06-02-sf2a-toulouse.md
# _talks/2016-06-19-nic14.md
# _talks/2017-07-04-sf2a-paris.md
# _talks/2017-11-13-cemp-galah.md
# _talks/2018-03-14-chetec.md
# _talks/2018-05-23-frontiers.md
# _talks/2019-02-21-konan.md
# _talks/2019-02-28-tohoku.md
# _talks/2019-03-08-naoj.md
# _talks/2019-03-12-tokyo-university.md
# _talks/2019-04-25-kyoto.md
# _talks/2019-06-18-lamost.md
# _talks/2019-07-02-omeg15.md
# _talks/2019-09-01-npa9.md
# _talks/2019-09-09-cemp.md
# _talks/2019-11-11-first-stars-galaxies.md
# _talks/2019-12-04-irena-naoj.md
# _talks/2020-03-03-firststars6.md
# _talks/2021-01-27-ulb.md
# _talks/2021-12-17-irena.md
# _talks/2022-02-02-geneva-observatory.md
# _talks/2022-05-18-starex.md
# _talks/2022-06-12-ari.md
# _talks/2022-06-19-torino13-perugia3.md
# _talks/2022-09-04-npa10.md
# _talks/2022-10-31-canpan.md
# _talks/2022-12-08-iphc.md
# _talks/2023-05-15-iprocess.md
# _talks/2024-04-19-stockholm.md
# _talks/2024-06-10-torino14.md
# _talks/2024-09-15-npa11.md
# _talks/2024-10-06-phynube.md
# _talks/2024-10-16-pprocess.md
# _talks/2025-01-17-irena.md
# _talks/2025-04-29-inaf-abruzzo.md
# _talks/2025-06-08-siren.md
# _talks/2025-06-15-nic18.md
# _talks/2025-11-03-ECT.md
# _talks/2026-03-16-keele.md

# %%
# Set the default timeout, in seconds
TIMEOUT = 5

# Prepare to geolocate
geocoder = Nominatim(user_agent="academicpages.github.io")
location_dict = {}
location = ""
permalink = ""
title = ""

# %% [markdown]
# In the event that this times out with an error, double check to make sure that the location is can be properly geolocated.

# %%
# Perform geolocation
for file in g:
    # Read the file
    data = frontmatter.load(file)
    data = data.to_dict()

    print("PROCESSING:", file)

    # Press on if the location is not present
    if 'location' not in data:
        continue

    # Prepare the description
    title = data['title'].strip()
    venue = data['venue'].strip()
    location = data['location'].strip()

    if location.lower() == "online":
        location = None
        continue

    print("TITLE:", title)
    print("LOCATION:", location)

    talk_type = data.get('type', 'Other')
    #description = f"{title}<br />{venue}; {location}"
    description = f"[{talk_type}]<br />{title}<br />{venue}; {location}"

    # Geocode the location and report the status
    try:
        #location_dict[description] = geocoder.geocode(location, timeout=TIMEOUT)
        #print(description, location_dict[description])
        result = geocoder.geocode(location, timeout=TIMEOUT)
        print("RESULT:", result)
        location_dict[description] = result
        time.sleep(1)
    except ValueError as ex:
        print(f"Error: geocode failed on input {location} with message {ex}")
    except GeocoderTimedOut as ex:
        print(f"Error: geocode timed out on input {location} with message {ex}")
    except Exception as ex:
        print(f"An unhandled exception occurred while processing input {location} with message {ex}")
# Out:
# PROCESSING: _talks/2022-06-19-torino13-perugia3.md
# TITLE: 13th Torino Workshop on AGB Stars & 3rd Perugia Workshop on Nuclear Astrophysics
# LOCATION: Perugia, Italy
# RESULT: Perugia, Umbria, Italia
# PROCESSING: _talks/2019-12-04-irena-naoj.md
# TITLE: JINA-CEE IReNA / NAOJ Meeting
# LOCATION: Tokyo, Japan
# RESULT: 東京都, 日本
# PROCESSING: _talks/2023-05-15-iprocess.md
# TITLE: i-process Nucleosynthesis Workshop
# LOCATION: Limassol, Cyprus
# RESULT: Λεμεσός, Δήμος Λεμεσού, Επαρχία Λεμεσού, Κύπρος, 3085, Κύπρος - Kıbrıs
# PROCESSING: _talks/2024-06-10-torino14.md
# TITLE: 14th Torino Workshop on AGB Stars
# LOCATION: Rome, Italy
# RESULT: Roma, Roma Capitale, Lazio, Italia
# PROCESSING: _talks/2025-04-29-inaf-abruzzo.md
# PROCESSING: _talks/2025-06-08-siren.md
# TITLE: s, i & r Element Nucleosynthesis Conference
# LOCATION: Giulianova, Italy
# RESULT: Giulianova, Teramo, Abruzzo, Italia
# PROCESSING: _talks/2019-04-25-kyoto.md
# TITLE: Department of Astronomy Seminar
# LOCATION: Kyoto University, Kyoto, Japan
# RESULT: 京都大学, 近衛通り, 吉田下阿達町, 吉田上大路町, 左京区, 京都市, 京都府, 606-8315, 日本
# PROCESSING: _talks/2016-06-19-nic14.md
# TITLE: Nuclei in the Cosmos XIV
# LOCATION: Niigata, Japan
# RESULT: 新潟県, 日本
# PROCESSING: _talks/2019-11-11-first-stars-galaxies.md
# TITLE: First Stars and First Galaxies Meeting
# LOCATION: Nagoya, Japan
# RESULT: 名古屋市, 愛知県, 日本
# PROCESSING: _talks/2024-10-06-phynube.md
# TITLE: 3rd Rencontre PhyNuBE: Fission and Nuclear Astrophysics
# LOCATION: Oléron, France
# RESULT: Saint-Pierre-d'Oléron, Rochefort, Charente-Maritime, Nouvelle-Aquitaine, France métropolitaine, 17310, France
# PROCESSING: _talks/2022-10-31-canpan.md
# TITLE: CaNPAN Annual Meeting
# LOCATION: TRIUMF, Vancouver BC, Canada
# RESULT: TRIUMF, 4004, Wesbrook Mall, University of British Columbia Vancouver, University of British Columbia, Electoral Area A, Metro Vancouver Regional District, British Columbia, V6S 0M8, Canada
# PROCESSING: _talks/2019-09-01-npa9.md
# TITLE: Nuclear Physics in Astrophysics IX
# LOCATION: Frankfurt, Germany
# RESULT: Frankfurt am Main, Hessen, Deutschland
# PROCESSING: _talks/2025-06-15-nic18.md
# TITLE: Nuclei in the Cosmos XVIII, Girona, Spain
# LOCATION: Girona, Spain
# RESULT: Girona, Gironès, Girona, Catalunya, España
# PROCESSING: _talks/2019-03-08-naoj.md
# TITLE: High Dispersion Spectrograph Seminar
# LOCATION: National Astronomical Observatory of Japan, Tokyo, Japan
# RESULT: None
# PROCESSING: _talks/2019-03-12-tokyo-university.md
# TITLE: Astronomy Department Seminar
# LOCATION: The University of Tokyo, Tokyo, Japan
# RESULT: 東京藝術大学, 1, 千住一丁目, 千住, 足立区, 東京都, 120-0034, 日本
# PROCESSING: _talks/2019-07-02-omeg15.md
# TITLE: 15th International Symposium on Origin of Matter and Evolution of Galaxies
# LOCATION: Kyoto, Japan
# RESULT: 京都市, 京都府, 日本
# PROCESSING: _talks/2021-01-27-ulb.md
# TITLE: Institute of Astronomy and Astrophysics Seminar
# LOCATION: Université Libre de Bruxelles, Brussels, Belgium
# RESULT: Université libre de Bruxelles (Campus du Solbosch), Avenue Brillat-Savarin - Brillat-Savarinlaan, Petite Suisse - Klein-Zwitserland, Ixelles - Elsene, Brussel-Hoofdstad - Bruxelles-Capitale, Région de Bruxelles-Capitale - Brussels Hoofdstedelijk Gewest, 1050, België / Belgique / Belgien
# PROCESSING: _talks/2019-09-09-cemp.md
# TITLE: CEMP Stars as Probes of First-Star Nucleosynthesis, the IMF, and Galactic Assembly
# LOCATION: Geneva, Switzerland
# RESULT: Genève, Schweiz/Suisse/Svizzera/Svizra
# PROCESSING: _talks/2017-07-04-sf2a-paris.md
# TITLE: Annual Meeting of the French Society of Astronomy and Astrophysics
# LOCATION: Paris, France
# RESULT: Paris, Île-de-France, France métropolitaine, France
# PROCESSING: _talks/2019-06-18-lamost.md
# TITLE: LAMOST Meeting
# LOCATION: National Astronomical Observatory of Japan, Tokyo, Japan
# RESULT: None
# PROCESSING: _talks/2021-12-17-irena.md
# PROCESSING: _talks/2024-09-15-npa11.md
# TITLE: Nuclear Physics in Astrophysics XI
# LOCATION: Dresden, Germany
# RESULT: Dresden, Sachsen, Deutschland
# PROCESSING: _talks/2020-03-03-firststars6.md
# TITLE: First Stars VI
# LOCATION: Concepción, Chile
# RESULT: Concepción, Provincia de Concepción, Región del Biobío, Chile
# PROCESSING: _talks/2022-09-04-npa10.md
# TITLE: Nuclear Physics in Astrophysics X
# LOCATION: Geneva, Switzerland
# RESULT: Genève, Schweiz/Suisse/Svizzera/Svizra
# PROCESSING: _talks/2024-10-16-pprocess.md
# TITLE: 8th p-process workshop
# LOCATION: Budapest, Hungary
# RESULT: Budapest, Közép-Magyarország, Magyarország
# PROCESSING: _talks/2022-06-12-ari.md
# TITLE: Astrophysics with Radioactive Isotopes
# LOCATION: Budapest, Hungary
# RESULT: Budapest, Közép-Magyarország, Magyarország
# PROCESSING: _talks/2026-03-16-keele.md
# TITLE: Astro Seminar Series
# LOCATION: Keele, UK
# RESULT: Keele, Newcastle-under-Lyme, Staffordshire, England, United Kingdom
# PROCESSING: _talks/2025-01-17-irena.md
# PROCESSING: _talks/2022-12-08-iphc.md
# TITLE: IPHC Seminar
# LOCATION: IPHC, Strasbourg, France
# RESULT: Centre National de la Recherche Scientifique - IPHC, Rue Becquerel, Cronenbourg, Strasbourg, Bas-Rhin, Collectivité européenne d'Alsace, Grand Est, France métropolitaine, 67200, France
# PROCESSING: _talks/2022-05-18-starex.md
# PROCESSING: _talks/2022-02-02-geneva-observatory.md
# PROCESSING: _talks/2017-11-13-cemp-galah.md
# TITLE: A Celebration of CEMP and Gala of GALAH
# LOCATION: Melbourne, Australia
# RESULT: Melbourne, Victoria, Australia
# PROCESSING: _talks/2024-04-19-stockholm.md
# TITLE: Department of Astronomy Seminar
# LOCATION: Stockholm University, Stockholm, Sweden
# RESULT: Stockholms universitet, Svante Arrhenius väg, Lappkärrsberget, Norra Djurgården, Norra innerstadens stadsdelsområde, Stockholm, Stockholms kommun, Stockholms län, 114 17, Sverige
# PROCESSING: _talks/2018-03-14-chetec.md
# TITLE: ChETEC COST Action Meeting
# LOCATION: Vilnius, Lithuania
# RESULT: Vilnius, Vilniaus miesto savivaldybė, Vilniaus apskritis, Lietuva
# PROCESSING: _talks/2019-02-21-konan.md
# TITLE: Department Seminar
# LOCATION: Konan University, Kobe, Japan
# RESULT: 甲南大学, 1, 岡本八丁目, 東灘区, 神戸市, 兵庫県, 658-8501, 日本
# PROCESSING: _talks/2018-05-23-frontiers.md
# TITLE: JINA-CEE Frontiers in Nuclear Astrophysics
# LOCATION: South Bend, IN, USA
# RESULT: South Bend, Saint Joseph County, Indiana, United States
# PROCESSING: _talks/2015-06-02-sf2a-toulouse.md
# TITLE: Annual Meeting of the French Society of Astronomy and Astrophysics
# LOCATION: Toulouse, France
# RESULT: Toulouse, Haute-Garonne, Occitanie, France métropolitaine, France
# PROCESSING: _talks/2019-02-28-tohoku.md
# TITLE: Astronomical Institute Seminar
# LOCATION: Tohoku University, Sendai, Japan
# RESULT: 東北大学 青葉山東キャンパス, 6, 青葉区, 仙台市, 宮城県, 980-8579, 日本
# PROCESSING: _talks/2025-11-03-ECT.md
# TITLE: ECT* Workshop: neutron-capture reactions for astrophysical processes
# LOCATION: Trento, Italy
# RESULT: Provincia di Trento, Trentino-Alto Adige/Südtirol, Italia

# %%
# Save the map
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'

# %%
#ajouté pour modifier map.htlm 
from pathlib import Path

mapfile = Path("talkmap/map.html")

html = mapfile.read_text(encoding="utf-8")

# Ajouter la fonction markerColor avant la boucle
html = html.replace(
    "for (var i = 0; i < addressPoints.length; i++) {",
    """
function markerColor(title) {

    if(title.includes("[Seminar]"))
        return "purple";

    if(title.includes("[Poster]"))
        return "blue";

    if(title.includes("[Invited talk]"))
        return "red";

    if(title.includes("[Invited review]"))
        return "darkred";

    if(title.includes("[Invited lecture]"))
        return "darkred";

    if(title.includes("[Oral contribution]"))
        return "green";

    return "orange";
}

for (var i = 0; i < addressPoints.length; i++) {
"""
)

# Remplacer le marqueur standard
html = html.replace(
    "var marker = L.marker(new L.LatLng(a[1], a[2]), { title: title });",
    """
var iconColor = markerColor(title);

var marker = L.marker(
    new L.LatLng(a[1], a[2]),
    {
        title: title,
        icon: new L.Icon({
            iconUrl:
                'https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-' +
                iconColor +
                '.png',
            shadowUrl:
                'https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.7/images/marker-shadow.png',
            iconSize: [25, 41],
            iconAnchor: [12, 41],
            popupAnchor: [1, -34],
            shadowSize: [41, 41]
        })
    }
);
"""
)

# Ajouter la légende
html = html.replace(
    "map.zoomIn();",
    """
map.zoomIn();

var legend = L.control({position: 'bottomright'});

legend.onAdd = function () {

    var div = L.DomUtil.create('div', 'info legend');

    div.style.backgroundColor = 'white';
    div.style.padding = '10px';
    div.style.border = '1px solid #999';

    div.innerHTML =
        '<b>Talk type</b><br>' +
        '<i style="background:red;width:12px;height:12px;display:inline-block;margin-right:5px;"></i> Invited talk<br>' +
        '<i style="background:darkred;width:12px;height:12px;display:inline-block;margin-right:5px;"></i> Invited review / lecture<br>' +
        '<i style="background:green;width:12px;height:12px;display:inline-block;margin-right:5px;"></i> Oral contribution<br>' +
        '<i style="background:blue;width:12px;height:12px;display:inline-block;margin-right:5px;"></i> Poster<br>' +
        '<i style="background:purple;width:12px;height:12px;display:inline-block;margin-right:5px;"></i> Seminar';

    return div;
};

legend.addTo(map);
"""
)

mapfile.write_text(html, encoding="utf-8")

print("Custom map styling applied.")
# Out:
# Custom map styling applied.
